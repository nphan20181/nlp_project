# %%
import pandas as pd

# Read cleaned data
df = pd.read_csv('https://raw.githubusercontent.com/nphan20181/nlp_project/main/data/data_cleaned.csv')

# Preview cleaned data
df.head()
# Out:
#                                                Title  ...                                   Keywords_Cleaned
# 0  Predictive Modeling Applied to Structured Clin...  ...  electron health record, fi nnish diabet r isk ...
# 1  Predicting Risk of Diabetes using a Model base...  ...  diabet risk prediction, fi nnish diabet r isk ...
# 2  Impact and Control of Drug Therapy Guidelines ...  ...          covid 19, cancer, pneumonia and healthcar
# 3  Structural Equation Model (SEM) for Evaluating...  ...  ict4d, success factors, structur equat model a...
# 4  Extended Fuzzy Decision Support Model for Crop...  ...  fuzzi logic, decis support model, euclidean di...
#
# [5 rows x 14 columns]
