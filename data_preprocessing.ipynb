# %% [markdown]
# # Data Preprocessing
#
# This notebook performs data preprocessing on the raw data.

# %%
import pandas as pd

# load data frame
df = pd.read_csv('data/article_full_text.csv')

# delete the first column, "Unnamed: 0"
df.drop(columns=['Unnamed: 0'], inplace=True)

# display the first 5 rows
df.head(5)
# Out:
#                                                Title  \
# 0  Predictive Modeling Applied to Structured Clin...
# 1  Predicting Risk of Diabetes using a Model base...
# 2  Impact and Control of Drug Therapy Guidelines ...
# 3  Structural Equation Model (SEM) for Evaluating...
# 4  Extended Fuzzy Decision Support Model for Crop...
#
#                                             Abstract  \
# 0  Predictive analysis is one of current importan...
# 1  Diabetes (diabetes mellitus) is a disease emer...
# 2  Since December 2019, many unexplained viral pn...
# 3  Information Communication Technology for Devel...
# 4  Food crops are the preferred crops to be culti...
#
#                                             Keywords  \
# 0  Electronic Health Record, FI Nnish Diabetes R ...
# 1  Diabetes Risk Prediction, FI Nnish Diabetes R ...
# 2         COVID-19, Cancer, Pneumonia and Healthcare
# 3  ICT4D, Success Factors, Structural Equation Mo...
# 4  Fuzzy Logic, Decision Support Model, Euclidean...
#
#                           File Name  \
# 0  2021_17_9_jcssp.2021.762.775.pdf
# 1  2021_17_9_jcssp.2021.748.761.pdf
# 2  2021_17_8_jcssp.2021.738.747.pdf
# 3  2021_17_8_jcssp.2021.724.737.pdf
# 4  2021_17_8_jcssp.2021.709.723.pdf
#
#                                                 URL  \
# 0  https://thescipub.com/pdf/jcssp.2021.762.775.pdf
# 1  https://thescipub.com/pdf/jcssp.2021.748.761.pdf
# 2  https://thescipub.com/pdf/jcssp.2021.738.747.pdf
# 3  https://thescipub.com/pdf/jcssp.2021.724.737.pdf
# 4  https://thescipub.com/pdf/jcssp.2021.709.723.pdf
#
#                                                 Text
# 0  Electronic Health Record (EHR) is the set of c...
# 1  The diseases prevention is one of the topic of...
# 2  A. The Possible Impact of NCP Epidemic on Canc...
# 3  Information Communication Technology for Devel...
# 4  Food crop productivity is determined by the qu...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2682 entries, 0 to 2681
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      2682 non-null   object
#  1   Abstract   2682 non-null   object
#  2   Keywords   2676 non-null   object
#  3   File Name  2682 non-null   object
#  4   URL        2682 non-null   object
#  5   Text       2640 non-null   object
# dtypes: object(6)
# memory usage: 125.8+ KB

# %%
# exclude articles that have missing text
data = df[df['Text'].notnull()].copy()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2640 entries, 0 to 2679
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      2640 non-null   object
#  1   Abstract   2640 non-null   object
#  2   Keywords   2634 non-null   object
#  3   File Name  2640 non-null   object
#  4   URL        2640 non-null   object
#  5   Text       2640 non-null   object
# dtypes: object(6)
# memory usage: 144.4+ KB

# %% [markdown]
# ## Extract Year, Volume Number, and Issue Number

# %%
data['Year'] = data['File Name'].apply(lambda x: x.split('_')[0])
data['Volume#'] = data['File Name'].apply(lambda x: x.split('_')[1])
data['Issue#'] = data['File Name'].apply(lambda x: x.split('_')[2])

# drop column "File Name"
data.drop('File Name', axis=1, inplace=True)

# display the first 5 rows
data.head()
# Out:
#                                                Title  \
# 0  Predictive Modeling Applied to Structured Clin...
# 1  Predicting Risk of Diabetes using a Model base...
# 2  Impact and Control of Drug Therapy Guidelines ...
# 3  Structural Equation Model (SEM) for Evaluating...
# 4  Extended Fuzzy Decision Support Model for Crop...
#
#                                             Abstract  \
# 0  Predictive analysis is one of current importan...
# 1  Diabetes (diabetes mellitus) is a disease emer...
# 2  Since December 2019, many unexplained viral pn...
# 3  Information Communication Technology for Devel...
# 4  Food crops are the preferred crops to be culti...
#
#                                             Keywords  \
# 0  Electronic Health Record, FI Nnish Diabetes R ...
# 1  Diabetes Risk Prediction, FI Nnish Diabetes R ...
# 2         COVID-19, Cancer, Pneumonia and Healthcare
# 3  ICT4D, Success Factors, Structural Equation Mo...
# 4  Fuzzy Logic, Decision Support Model, Euclidean...
#
#                                                 URL  \
# 0  https://thescipub.com/pdf/jcssp.2021.762.775.pdf
# 1  https://thescipub.com/pdf/jcssp.2021.748.761.pdf
# 2  https://thescipub.com/pdf/jcssp.2021.738.747.pdf
# 3  https://thescipub.com/pdf/jcssp.2021.724.737.pdf
# 4  https://thescipub.com/pdf/jcssp.2021.709.723.pdf
#
#                                                 Text  Year Volume# Issue#
# 0  Electronic Health Record (EHR) is the set of c...  2021      17      9
# 1  The diseases prevention is one of the topic of...  2021      17      9
# 2  A. The Possible Impact of NCP Epidemic on Canc...  2021      17      8
# 3  Information Communication Technology for Devel...  2021      17      8
# 4  Food crop productivity is determined by the qu...  2021      17      8

# %% [markdown]
# ## Missing Values

# %%
# look at the articles that have missing keywords
missing_keywords = data[data['Keywords'].isnull()].copy()
missing_keywords

# after reviewing at the pdf files, the following articles needed to be removed
# - the first 3s have only 1 page and do not contain article's text 
# - the article at index 968 does not have a keyword and does not follow a standard structure of a literature review
# - the article at index 986 has only 1 page, and do not contain relevant text
# Out:
#                                                  Title  \
# 422  Corrigendum: An Efficient Cell Placement Using...
# 423  Corrigendum: Adaptive Resonance Theory Trainin...
# 424  Corrigendum: Simulated Annealing with Determin...
# 771  A MOBILE AGENT BASED APPROACH FOR AUTOMATING &...
# 968  Data Mining in Time Series: Current Study and ...
# 986  EMERGING TRENDS IN ADAPTIVE COMPUTATION FOR MO...
#
#                                               Abstract Keywords  \
# 422  Correction to: Journal of Computer Science htt...      NaN
# 423  Correction to: Journal of Computer Science htt...      NaN
# 424  Correction to: Journal of Computer Science htt...      NaN
# 771  Nowadays, the focus is not only on how to exch...      NaN
# 968  Time series represent sequences of data points...      NaN
# 986  The future is in networked embedded systems. T...      NaN
#
#                                                    URL  \
# 422       https://thescipub.com/pdf/jcssp.2018.437.pdf
# 423       https://thescipub.com/pdf/jcssp.2018.436.pdf
# 424       https://thescipub.com/pdf/jcssp.2018.435.pdf
# 771  https://thescipub.com/pdf/jcssp.2014.1628.1641...
# 968  https://thescipub.com/pdf/jcssp.2014.2358.2359...
# 986  https://thescipub.com/pdf/jcssp.2014.2164.2164...
#
#                                                   Text  Year Volume# Issue#
# 422  © 2018 The Author(s). This open access article...  2018      14      3
# 423  © 2018 The Author(s). This open access article...  2018      14      3
# 424  © 2018 The Author(s). This open access article...  2018      14      3
# 771  A web service is a computer program for commun...  2014      10      9
# 968  Journal of Computer Science 10 (12): 2358-2359...  2014      10     12
# 986  Journal of Computer Science 10 (11): 2164, 201...  2014      10     11

# %%
# update the keywords to article at row 771
# since index 771 is based on index starting position of 1
# to perform row update using index location, we need to minus 1 from 771
data.iloc[770].Keywords = 'Semantic Web Services, Semantic Web Services Discovery, Semantic Web Services Composition, Ontology, Mobile Agent, JADE'

# make sure data has been updated
data.iloc[770]
# Out:
# Title       A MOBILE AGENT BASED APPROACH FOR AUTOMATING &...
# Abstract    Nowadays, the focus is not only on how to exch...
# Keywords    Semantic Web Services, Semantic Web Services D...
# URL         https://thescipub.com/pdf/jcssp.2014.1628.1641...
# Text        A web service is a computer program for commun...
# Year                                                     2014
# Volume#                                                    10
# Issue#                                                      9
# Name: 771, dtype: object

# %%
# check if row 771 has been updated -- it should not be shown up in the table below
# look at the articles that have missing keywords
missing_keywords = data[data['Keywords'].isnull()].copy()
missing_keywords
# Out:
#                                                  Title  \
# 422  Corrigendum: An Efficient Cell Placement Using...
# 423  Corrigendum: Adaptive Resonance Theory Trainin...
# 424  Corrigendum: Simulated Annealing with Determin...
# 968  Data Mining in Time Series: Current Study and ...
# 986  EMERGING TRENDS IN ADAPTIVE COMPUTATION FOR MO...
#
#                                               Abstract Keywords  \
# 422  Correction to: Journal of Computer Science htt...      NaN
# 423  Correction to: Journal of Computer Science htt...      NaN
# 424  Correction to: Journal of Computer Science htt...      NaN
# 968  Time series represent sequences of data points...      NaN
# 986  The future is in networked embedded systems. T...      NaN
#
#                                                    URL  \
# 422       https://thescipub.com/pdf/jcssp.2018.437.pdf
# 423       https://thescipub.com/pdf/jcssp.2018.436.pdf
# 424       https://thescipub.com/pdf/jcssp.2018.435.pdf
# 968  https://thescipub.com/pdf/jcssp.2014.2358.2359...
# 986  https://thescipub.com/pdf/jcssp.2014.2164.2164...
#
#                                                   Text  Year Volume# Issue#
# 422  © 2018 The Author(s). This open access article...  2018      14      3
# 423  © 2018 The Author(s). This open access article...  2018      14      3
# 424  © 2018 The Author(s). This open access article...  2018      14      3
# 968  Journal of Computer Science 10 (12): 2358-2359...  2014      10     12
# 986  Journal of Computer Science 10 (11): 2164, 201...  2014      10     11

# %%
# get the index of missing values
removed_rows = list(missing_keywords.index)
print(removed_rows)
# Out:
# [422, 423, 424, 968, 986]

# %%
# drop the rows in the removed_rows list
data.drop(index=removed_rows, inplace=True)

# check if there are any missing values left
data[data['Keywords'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Title, Abstract, Keywords, URL, Text, Year, Volume#, Issue#]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2635 entries, 0 to 2679
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     2635 non-null   object
#  1   Abstract  2635 non-null   object
#  2   Keywords  2635 non-null   object
#  3   URL       2635 non-null   object
#  4   Text      2635 non-null   object
#  5   Year      2635 non-null   object
#  6   Volume#   2635 non-null   object
#  7   Issue#    2635 non-null   object
# dtypes: object(8)
# memory usage: 185.3+ KB

# %% [markdown]
# ## Plagiarized / Retracted Articles

# %%
data.describe()
# Out:
#                                                     Title  \
# count                                                2635
# unique                                               2635
# top     Improving Response Time of Authorization Proce...
# freq                                                    1
#
#                                                  Abstract  \
# count                                                2635
# unique                                               2633
# top     Publication of this article is cancelled due t...
# freq                                                    2
#
#                                                  Keywords  \
# count                                                2635
# unique                                               2630
# top     Plastic Optical Fiber, Demultiplexer, Spectral...
# freq                                                    3
#
#                                                      URL  \
# count                                               2635
# unique                                              2635
# top     https://thescipub.com/pdf/jcssp.2007.134.137.pdf
# freq                                                   1
#
#                                                      Text  Year Volume# Issue#
# count                                                2635  2635    2635   2635
# unique                                               2635    17      17     12
# top     Speech and natural language understanding are ...  2014      10      1
# freq                                                    1   290     290    239

# %%
data.describe().Abstract.top
# Out:
# 'Publication of this article is cancelled due to plagiarism.'

# %%
# look at the plagarized articles
data[data['Abstract'] == 'Publication of this article is cancelled due to plagiarism.']
# Out:
#                                                   Title  \
# 2179  RETRACTED: Object Oriented and Multi-Scale Ima...
# 2389  RETRACTED: A Bayesian Networks in Intrusion De...
#
#                                                Abstract  \
# 2179  Publication of this article is cancelled due t...
# 2389  Publication of this article is cancelled due t...
#
#                                                Keywords  \
# 2179  Object based image analysis, hierarchical netw...
# 2389  Computer network, Security, Intrusion detectio...
#
#                                                    URL  \
# 2179  https://thescipub.com/pdf/jcssp.2008.706.712.pdf
# 2389  https://thescipub.com/pdf/jcssp.2007.259.265.pdf
#
#                                                    Text  Year Volume# Issue#
# 2179  What is OBIA?: In the absence of a formal defi...  2008       4      9
# 2389  Intrusion detection can be defined as the proc...  2007       3      5

# %%
# exclude plagarized articles from the data
data = data[data['Abstract'] != 'Publication of this article is cancelled due to plagiarism.']

# display data info
data.info()

# describe data
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2633 entries, 0 to 2679
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     2633 non-null   object
#  1   Abstract  2633 non-null   object
#  2   Keywords  2633 non-null   object
#  3   URL       2633 non-null   object
#  4   Text      2633 non-null   object
#  5   Year      2633 non-null   object
#  6   Volume#   2633 non-null   object
#  7   Issue#    2633 non-null   object
# dtypes: object(8)
# memory usage: 185.1+ KB
#                                                     Title  \
# count                                                2633
# unique                                               2633
# top     Improving Response Time of Authorization Proce...
# freq                                                    1
#
#                                                  Abstract  \
# count                                                2633
# unique                                               2632
# top     This article has been retracted at the request...
# freq                                                    2
#
#                                                  Keywords  \
# count                                                2633
# unique                                               2628
# top     Plastic Optical Fiber, Demultiplexer, Spectral...
# freq                                                    3
#
#                                                      URL  \
# count                                               2633
# unique                                              2633
# top     https://thescipub.com/pdf/jcssp.2007.134.137.pdf
# freq                                                   1
#
#                                                      Text  Year Volume# Issue#
# count                                                2633  2633    2633   2633
# unique                                               2633    17      17     12
# top     Speech and natural language understanding are ...  2014      10      1
# freq                                                    1   290     290    239

# %%
data.describe().Abstract.top
# Out:
# 'This article has been retracted at the request of the authors.'

# %%
# exclude retracted articles from the data
data = data[data['Abstract'] != 'This article has been retracted at the request of the authors.']

# display data info
data.info()

# describe data
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2631 entries, 0 to 2679
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     2631 non-null   object
#  1   Abstract  2631 non-null   object
#  2   Keywords  2631 non-null   object
#  3   URL       2631 non-null   object
#  4   Text      2631 non-null   object
#  5   Year      2631 non-null   object
#  6   Volume#   2631 non-null   object
#  7   Issue#    2631 non-null   object
# dtypes: object(8)
# memory usage: 185.0+ KB
#                                                     Title  \
# count                                                2631
# unique                                               2631
# top     Improving Response Time of Authorization Proce...
# freq                                                    1
#
#                                                  Abstract  \
# count                                                2631
# unique                                               2631
# top     Problem statement: The phenomenon of flashover...
# freq                                                    1
#
#                                                  Keywords  \
# count                                                2631
# unique                                               2626
# top     Plastic Optical Fiber, Demultiplexer, Spectral...
# freq                                                    3
#
#                                                      URL  \
# count                                               2631
# unique                                              2631
# top     https://thescipub.com/pdf/jcssp.2007.134.137.pdf
# freq                                                   1
#
#                                                      Text  Year Volume# Issue#
# count                                                2631  2631    2631   2631
# unique                                               2631    17      17     12
# top     Speech and natural language understanding are ...  2014      10      1
# freq                                                    1   290     290    239

# %% [markdown]
# ## Save Data

# %%
data.to_csv('data/article_fulltext_preprocessed.csv', index=False)
