# %% [markdown]
# # Data Preprocessing
#
# This notebook performs data preprocessing on the raw data.

# %%
import pandas as pd

# load data frame
df = pd.read_csv('data/article_full_text.csv')

# display the first 5 rows
df.head()
# Out:
#                          Date  \
# 0   Published: 8 January 2021
# 1  Published: 21 January 2021
# 2  Published: 20 January 2021
# 3  Published: 20 January 2021
# 4  Published: 21 January 2021
#
#                                                Title  \
# 0  A Systematic Literature Review on English and ...
# 1  DAD: A Detailed Arabic Dataset for Online Text...
# 2  Collision Avoidance Modelling in Airline Traff...
# 3  Fine-Tuned MobileNet Classifier for Classifica...
# 4  A Content Filtering from Spam Posts on Social ...
#
#                                             Abstract  \
# 0  Due to the enormous growth of information and ...
# 1  This paper presents a novel Arabic dataset tha...
# 2  An Air Traffic Controller (ATC) system aims to...
# 3  This paper proposed an accurate, fast and reli...
# 4  The system for filtering spam posts on social ...
#
#                                             Keywords  \
# 0  English Bangla Comparison, Latent Dirichlet Al...
# 1  Arabic Dataset, Arabic Benchmark, Arabic Recog...
# 2  Air Traffic Control, Collision Avoidance, Conf...
# 3  Strawberry, Cherry Fruit, Accuracy, MobileNet,...
# 4  Content Filtering, Spam Detection, Multimodal ...
#
#                         File Name  \
# 0   2021_17_1_jcssp.2021.1.18.pdf
# 1  2021_17_1_jcssp.2021.19.32.pdf
# 2  2021_17_1_jcssp.2021.33.43.pdf
# 3  2021_17_1_jcssp.2021.44.54.pdf
# 4  2021_17_1_jcssp.2021.55.66.pdf
#
#                                               URL  \
# 0   https://thescipub.com/pdf/jcssp.2021.1.18.pdf
# 1  https://thescipub.com/pdf/jcssp.2021.19.32.pdf
# 2  https://thescipub.com/pdf/jcssp.2021.33.43.pdf
# 3  https://thescipub.com/pdf/jcssp.2021.44.54.pdf
# 4  https://thescipub.com/pdf/jcssp.2021.55.66.pdf
#
#                                                 Text
# 0  Because of the rapid development of Informatio...
# 1  In the literature, many papers that focus on A...
# 2  Collision avoidance on air traffic becomes ver...
# 3  In recent years, farmers in India eventually l...
# 4  Spam is the use of electronic devices to trans...

# %% [markdown]
# ## Remove Rows with Missing Text and Keywords

# %%
# check for missing values in the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2691 entries, 0 to 2690
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2691 non-null   object
#  1   Title      2691 non-null   object
#  2   Abstract   2691 non-null   object
#  3   Keywords   2686 non-null   object
#  4   File Name  2691 non-null   object
#  5   URL        2691 non-null   object
#  6   Text       2651 non-null   object
# dtypes: object(7)
# memory usage: 147.3+ KB

# %%
# exclude articles that have missing text
data = df[df['Text'].notnull()].copy()

# exclude articles that have missing keywords
data = data[data['Keywords'].notnull()]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2646 entries, 0 to 2690
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2646 non-null   object
#  1   Title      2646 non-null   object
#  2   Abstract   2646 non-null   object
#  3   Keywords   2646 non-null   object
#  4   File Name  2646 non-null   object
#  5   URL        2646 non-null   object
#  6   Text       2646 non-null   object
# dtypes: object(7)
# memory usage: 165.4+ KB

# %% [markdown]
# ## Extract Year, Month, Volume Number, and Issue Number

# %%
# clean Date field
data['Date'] = data['Date'].apply(lambda x: x.split(':')[1].strip())

# extrac data from existing fields
data['Year'] = data['File Name'].apply(lambda x: x.split('_')[0])
data['Volume#'] = data['File Name'].apply(lambda x: x.split('_')[1])
data['Issue#'] = data['File Name'].apply(lambda x: x.split('_')[2])
data['Month'] = data['Date'].apply(lambda x: x.split(' ')[-2])

# drop column "File Name"
data.drop('File Name', axis=1, inplace=True)

# display the first 5 rows
data.head()
# Out:
#               Date                                              Title  \
# 0   8 January 2021  A Systematic Literature Review on English and ...
# 1  21 January 2021  DAD: A Detailed Arabic Dataset for Online Text...
# 2  20 January 2021  Collision Avoidance Modelling in Airline Traff...
# 3  20 January 2021  Fine-Tuned MobileNet Classifier for Classifica...
# 4  21 January 2021  A Content Filtering from Spam Posts on Social ...
#
#                                             Abstract  \
# 0  Due to the enormous growth of information and ...
# 1  This paper presents a novel Arabic dataset tha...
# 2  An Air Traffic Controller (ATC) system aims to...
# 3  This paper proposed an accurate, fast and reli...
# 4  The system for filtering spam posts on social ...
#
#                                             Keywords  \
# 0  English Bangla Comparison, Latent Dirichlet Al...
# 1  Arabic Dataset, Arabic Benchmark, Arabic Recog...
# 2  Air Traffic Control, Collision Avoidance, Conf...
# 3  Strawberry, Cherry Fruit, Accuracy, MobileNet,...
# 4  Content Filtering, Spam Detection, Multimodal ...
#
#                                               URL  \
# 0   https://thescipub.com/pdf/jcssp.2021.1.18.pdf
# 1  https://thescipub.com/pdf/jcssp.2021.19.32.pdf
# 2  https://thescipub.com/pdf/jcssp.2021.33.43.pdf
# 3  https://thescipub.com/pdf/jcssp.2021.44.54.pdf
# 4  https://thescipub.com/pdf/jcssp.2021.55.66.pdf
#
#                                                 Text  Year Volume# Issue#  \
# 0  Because of the rapid development of Informatio...  2021      17      1
# 1  In the literature, many papers that focus on A...  2021      17      1
# 2  Collision avoidance on air traffic becomes ver...  2021      17      1
# 3  In recent years, farmers in India eventually l...  2021      17      1
# 4  Spam is the use of electronic devices to trans...  2021      17      1
#
#      Month
# 0  January
# 1  January
# 2  January
# 3  January
# 4  January

# %% [markdown]
# ## Remove Plagiarized / Retracted Articles

# %%
data.describe()
# Out:
#                     Date                                              Title  \
# count               2646                                               2646
# unique              1040                                               2646
# top     31 December 2009  A Proposed Framework for Reducing Electricity ...
# freq                  30                                                  1
#
#                                                  Abstract  \
# count                                                2646
# unique                                               2644
# top     Publication of this article is cancelled due t...
# freq                                                    2
#
#                                                  Keywords  \
# count                                                2646
# unique                                               2641
# top     Plastic Optical Fiber, Demultiplexer, Spectral...
# freq                                                    3
#
#                                                      URL  \
# count                                               2646
# unique                                              2646
# top     https://thescipub.com/pdf/jcssp.2014.614.622.pdf
# freq                                                   1
#
#                                                      Text  Year Volume#  \
# count                                                2646  2646    2646
# unique                                               2646    17      17
# top     The signal processing plays an important role ...  2014      10
# freq                                                    1   290     290
#
#        Issue#     Month
# count    2646      2646
# unique     12        12
# top         1  November
# freq      240       253

# %%
data.describe().Abstract.top
# Out:
# 'Publication of this article is cancelled due to plagiarism.'

# %%
# look at the plagarized articles
data[data['Abstract'] == 'Publication of this article is cancelled due to plagiarism.']
# Out:
#                    Date                                              Title  \
# 2277  30 September 2008  RETRACTED: Object Oriented and Multi-Scale Ima...
# 2372        31 May 2007  RETRACTED: A Bayesian Networks in Intrusion De...
#
#                                                Abstract  \
# 2277  Publication of this article is cancelled due t...
# 2372  Publication of this article is cancelled due t...
#
#                                                Keywords  \
# 2277  Object based image analysis, hierarchical netw...
# 2372  Computer network, Security, Intrusion detectio...
#
#                                                    URL  \
# 2277  https://thescipub.com/pdf/jcssp.2008.706.712.pdf
# 2372  https://thescipub.com/pdf/jcssp.2007.259.265.pdf
#
#                                                    Text  Year Volume# Issue#  \
# 2277  What is OBIA?: In the absence of a formal defi...  2008       4      9
# 2372  Intrusion detection can be defined as the proc...  2007       3      5
#
#           Month
# 2277  September
# 2372        May

# %%
# exclude plagarized articles from the data
data = data[data['Abstract'] != 'Publication of this article is cancelled due to plagiarism.']

# display data info
data.info()

# describe data
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2644 entries, 0 to 2690
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2644 non-null   object
#  1   Title     2644 non-null   object
#  2   Abstract  2644 non-null   object
#  3   Keywords  2644 non-null   object
#  4   URL       2644 non-null   object
#  5   Text      2644 non-null   object
#  6   Year      2644 non-null   object
#  7   Volume#   2644 non-null   object
#  8   Issue#    2644 non-null   object
#  9   Month     2644 non-null   object
# dtypes: object(10)
# memory usage: 227.2+ KB
#                     Date                                              Title  \
# count               2644                                               2644
# unique              1040                                               2644
# top     31 December 2009  A Proposed Framework for Reducing Electricity ...
# freq                  30                                                  1
#
#                                                  Abstract  \
# count                                                2644
# unique                                               2643
# top     This article has been retracted at the request...
# freq                                                    2
#
#                                                  Keywords  \
# count                                                2644
# unique                                               2639
# top     Plastic Optical Fiber, Demultiplexer, Spectral...
# freq                                                    3
#
#                                                      URL  \
# count                                               2644
# unique                                              2644
# top     https://thescipub.com/pdf/jcssp.2014.614.622.pdf
# freq                                                   1
#
#                                                      Text  Year Volume#  \
# count                                                2644  2644    2644
# unique                                               2644    17      17
# top     The signal processing plays an important role ...  2014      10
# freq                                                    1   290     290
#
#        Issue#     Month
# count    2644      2644
# unique     12        12
# top         1  November
# freq      240       253

# %%
data.describe().Abstract.top
# Out:
# 'This article has been retracted at the request of the authors.'

# %%
# exclude retracted articles from the data
data = data[data['Abstract'] != 'This article has been retracted at the request of the authors.']

# display data info
data.info()

# describe data
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2642 entries, 0 to 2690
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2642 non-null   object
#  1   Title     2642 non-null   object
#  2   Abstract  2642 non-null   object
#  3   Keywords  2642 non-null   object
#  4   URL       2642 non-null   object
#  5   Text      2642 non-null   object
#  6   Year      2642 non-null   object
#  7   Volume#   2642 non-null   object
#  8   Issue#    2642 non-null   object
#  9   Month     2642 non-null   object
# dtypes: object(10)
# memory usage: 227.0+ KB
#                     Date                                              Title  \
# count               2642                                               2642
# unique              1039                                               2642
# top     31 December 2009  A Proposed Framework for Reducing Electricity ...
# freq                  30                                                  1
#
#                                                  Abstract  \
# count                                                2642
# unique                                               2642
# top     Problem statement: This study described the an...
# freq                                                    1
#
#                                                  Keywords  \
# count                                                2642
# unique                                               2637
# top     Plastic Optical Fiber, Demultiplexer, Spectral...
# freq                                                    3
#
#                                                      URL  \
# count                                               2642
# unique                                              2642
# top     https://thescipub.com/pdf/jcssp.2014.614.622.pdf
# freq                                                   1
#
#                                                      Text  Year Volume#  \
# count                                                2642  2642    2642
# unique                                               2642    17      17
# top     The signal processing plays an important role ...  2014      10
# freq                                                    1   290     290
#
#        Issue#     Month
# count    2642      2642
# unique     12        12
# top         1  November
# freq      240       253

# %% [markdown]
# ## Derived Features

# %%
# get title's length per article
data['Title Length'] = data.Title.str.len()

# get abstract's length per article
data['Abstract Length'] = data.Abstract.str.len()    

# get length of article's full text
data['Text Length'] = data.Text.str.len()  

# get number of keywords per article
data['Number of Keywords'] = data.Keywords.apply(lambda keywords: len(keywords.split(',')))

# %% [markdown]
# ## Text Length

# %%
data['Text Length'].describe()
# Out:
# count      2642.000000
# mean      17972.945117
# std       11124.030230
# min          49.000000
# 25%       10128.250000
# 50%       16710.000000
# 75%       23664.500000
# max      107028.000000
# Name: Text Length, dtype: float64

# %%
# only include articles with full text started with a capital letters
# this would exclude articles with invalid texts
data = data[data['Text'].str.contains('^[A-Z]+.*') == True].reset_index(drop=True)

# exclude articles with text length < 1000 words
data = data[data['Text Length'] > 1000].reset_index(drop=True)

# print data's shape and show the first 5 rows
print("Data shape:", data.shape)
data.head()
# Out:
# Data shape: (1811, 14)
#               Date                                              Title  \
# 0   8 January 2021  A Systematic Literature Review on English and ...
# 1  21 January 2021  DAD: A Detailed Arabic Dataset for Online Text...
# 2  20 January 2021  Collision Avoidance Modelling in Airline Traff...
# 3  20 January 2021  Fine-Tuned MobileNet Classifier for Classifica...
# 4  21 January 2021  A Content Filtering from Spam Posts on Social ...
#
#                                             Abstract  \
# 0  Due to the enormous growth of information and ...
# 1  This paper presents a novel Arabic dataset tha...
# 2  An Air Traffic Controller (ATC) system aims to...
# 3  This paper proposed an accurate, fast and reli...
# 4  The system for filtering spam posts on social ...
#
#                                             Keywords  \
# 0  English Bangla Comparison, Latent Dirichlet Al...
# 1  Arabic Dataset, Arabic Benchmark, Arabic Recog...
# 2  Air Traffic Control, Collision Avoidance, Conf...
# 3  Strawberry, Cherry Fruit, Accuracy, MobileNet,...
# 4  Content Filtering, Spam Detection, Multimodal ...
#
#                                               URL  \
# 0   https://thescipub.com/pdf/jcssp.2021.1.18.pdf
# 1  https://thescipub.com/pdf/jcssp.2021.19.32.pdf
# 2  https://thescipub.com/pdf/jcssp.2021.33.43.pdf
# 3  https://thescipub.com/pdf/jcssp.2021.44.54.pdf
# 4  https://thescipub.com/pdf/jcssp.2021.55.66.pdf
#
#                                                 Text  Year Volume# Issue#  \
# 0  Because of the rapid development of Informatio...  2021      17      1
# 1  In the literature, many papers that focus on A...  2021      17      1
# 2  Collision avoidance on air traffic becomes ver...  2021      17      1
# 3  In recent years, farmers in India eventually l...  2021      17      1
# 4  Spam is the use of electronic devices to trans...  2021      17      1
#
#      Month  Title Length  Abstract Length  Text Length  Number of Keywords
# 0  January            67             2773        48221                   6
# 1  January            96             2553        37984                   9
# 2  January           109             3375        30346                   4
# 3  January            87             3283        29159                   5
# 4  January            86             2745        30537                   5

# %%
data['Text Length'].describe()
# Out:
# count      1811.000000
# mean      22214.085036
# std       10103.870359
# min        2033.000000
# 25%       15473.000000
# 50%       20505.000000
# 75%       26867.500000
# max      107028.000000
# Name: Text Length, dtype: float64

# %% [markdown]
# ## Text Processing
#
# - Remove urls, figure texts, and footnote texts
# - Convert text to lowercase
# - Remove stopwords
# - Lemmatize full texts and abstracts
# - Apply stemming to keywords

# %%
import re

def clean_text(text):
    '''
    Strip off any urls, figure texts, and footnote texts
    '''
    
    patterns = [r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*',    # remove urls
                r'\s*\d+www\.\w+\d*\.\w+/\w+',
                r'DOI: \d+\.\d+/\w+\.\d+\.\d+\.\d+\s*',                 # remove DOI texts
                r'Fig.\s\d+:\s*',                                       # remove Fig texts
                r'Journal of Computer Science \d+,\s\d+\s\(\d+\):\s\d+\.\d+\s\d+\s*'] # remove footnote text  
    
    text_temp = text
    for pattern in patterns:
        text_temp = re.sub(pattern, '', text_temp, flags=re.MULTILINE)
    
    # convert text to lower case
    return text_temp.lower()

# %%
import nltk

# get unique English stopwords
stopwords = set(nltk.corpus.stopwords.words('english'))

def remove_stopwords(text):
    '''Remove stopwords from text'''
    return ' '.join([word for word in text.split(' ') if not word in stopwords])

# %%
regex = re.compile(r'[^\w\s]+')

def clean_text_2(text):
    '''Remove none-word characters'''
    
    # remove any extra spaces
    text_temp = re.sub(r'\s{2,}', ' ', text, flags=re.MULTILINE)
    
    # remove any none-word characters
    sentences = []
    for sent in text_temp.split('. '):
        sentences.append(' '.join([regex.sub('', word) for word in sent.split(' ')]))
    
    return '. '.join(sentences)

# %%
import spacy

# Initialize spacy 'en' model, keeping only tagger component needed for lemmatization
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

def lemmatize_text(text):
    # first split text into sentences based on the period
    sentences = text.split('. ')
    lemmas = []   # a list of lemmatized sentences
    
    for sent in sentences:
        # Parse the text using the loaded 'en' model object `nlp`
        doc = nlp(sent)
        
        # Extract the lemma for each token and join
        lemmas.append(" ".join([token.lemma_ for token in doc]))
    
    # return the lemmatized text
    return ". ".join(lemmas)

# %% [markdown]
# ### Article's Full Text

# %%
# remove invalid texts
data['Text_Cleaned'] = data.Text.apply(clean_text)

# remove stopwords from text
data['Text_Cleaned'] = data['Text_Cleaned'].apply(remove_stopwords)

# %%
# perform lemmatization on text
data['Text_Cleaned'] = data['Text_Cleaned'].apply(lemmatize_text)

# %%
# remove non-words characters
data['Text_Cleaned'] = data['Text_Cleaned'].apply(clean_text_2)

# look at the first article's cleaned text
data['Text_Cleaned'].values[0]
# Out:
# 'rapid development information technology  eg.  internet  social medium  online database  etc .   amount datum generate exponentially exacerbate recent year. vast accumulation datum provide essential support training machine learning model easy access search engine query. hand  massive flourish information  extract knowledge interest datum become matter general concern  xu et al .  2019 . accord study domo  a cloud  base business service system   roughly 25 quintilian byte datum produce daily 90  datum world create last two year  accord 2018 study   al helal mouhoub  2018 . feasible person sieve useful information vast amount datum manually. moreover  national science foundation scale scientific datum management data  intensive challenge area future study  karami et al .  2018 . crucial precisely efficiently estimate numerical characteristic  determine appropriate statistical distribution model text corpora  jiang et al .  2017 . topic model probabilistic approach observe instrument measurement hide structure document  shi et al .  2019 . infer hidden structure  pre  process document. first  extraneous word stop word remove text. punctuation also usually remove  researcher keep punctuation carry certain emotion meaning. word consider bi  gram  adjacent word often appear together   tri  gram  etc. one word. result list transform bag word  word md. basim uddin ahme et al.  count  document. weight assign word analyze they. give importance particular word  weight factor change  eg.  use term frequency  inverse document frequency tf  idf . pre  processed datum feed machine learn algorithm  lda  lsa  btm  etc . . algorithm iterate training datum several time try accurately infer latent topic collection document much possible. various parameter hyperparameter use algorithm. tune training phase model. model output document distribution topic topic mixture word. again  set topically  relate word generate associate document corpus  hasan et al .  2019 . infer topic huge collection document electronic archive  topic modeling use many real  world application as  topic extraction social site  eg.  twitter  facebook   alkhodair et al .  2018   classification clustering  ruohonen  2017  al helal mouhoub  2018   medical science  shovkun et al .  2018   recommendation feedback system  uteuov  2019  rahman dey  2018   spam detection  li et al .  2013   text summarization  chowdhury et al .  2017   etc. topic modeling algorithms research paper specific english language. frequently update survey  see internet content 259  english1 percentage may decrease come year. therefore  develop similar tool language essential. bangla language become one popular language world announcement annually observe february 21st international mother language day unesco november 17th  1999. around 228 million native speaker another 37 million second language speaker  bangla 5th speak native language 7th total number speaker world  wikipedia  2020 . though bangla popular language world  barely topic modeling technique study find. slr  provide comprehensive view topic modeling accord literature algorithm technique differ english bangla language. perform systematic study acquaint method  domain  dataset  etc. relate topic modeling show tabular diagram form. process help we understanws observation method different domain. also learn evaluate algorithm technique many evaluation matrix  also describe below. 1 wwwstatistacom  wwwinternetworldstatscom paper outline follow  briefly explain basic topic modeling section 2  detailed review process section 3 present result slr section 4. talk challenge future scope section 5. finally conclude work section 7. background section provide brief description topic modeling method use select paper. evaluation method topic modeling also introduce here. hopefully give reader basic idea model include review paper. topic modeling method topic model emerge machine learn technology widely use various field research  yuan et al .  2015 . basic  ...

# %% [markdown]
# ### Abstracts

# %%
# convert text to lower case
data['Abstract_Cleaned'] = data['Abstract'].map(lambda text: text.lower())

# remove stopwords
data['Abstract_Cleaned'] = data['Abstract_Cleaned'].apply(remove_stopwords)

# %%
# perform lemmatization
data['Abstract_Cleaned'] = data['Abstract_Cleaned'].apply(lemmatize_text)

# %%
# remove any non-words character
data['Abstract_Cleaned'] = data['Abstract_Cleaned'].apply(clean_text_2)

# look at the first abstract
data['Abstract_Cleaned'].values[0]
# Out:
# 'due enormous growth information technology  digitize text datum immensely generate. therefore  identify main topic vast collection document human merely impossible. topic model statistical framework infer latent underlie topic text document  corpus  electronic archive probabilistic approach. promise field natural language processing  nlp . though many researcher research field  significant research do bangla. literature review paper  follow systematic approach review topic model study publish 2003 2020. analyze topic modeling method different aspect identify research gap topic model english bangla language. analyze paper  identify several type topic modeling technique  latent dirichlet allocation  lda   latent semantic analysis  lsa   support vector machine  svm   bi  term topic modeling  btm . furthermore  review paper also highlight real  world application topic model. several evaluation method use evaluate model  performance  discuss study. conclude mention huge future research scope topic model bangla. due enormous growth information technology  digitize text datum immensely generate. therefore  identify main topic vast collection document human merely impossible. topic model statistical framework infer latent underlie topic text document  corpus  electronic archive probabilistic approach. promise field natural language processing  nlp . though many researcher research field  significant research do bangla. literature review paper  follow systematic approach review topic model study publish 2003 2020. analyze topic modeling method different aspect identify research gap topic model english bangla language. analyze paper  identify several type topic modeling technique  latent dirichlet allocation  lda   latent semantic analysis  lsa   support vector machine  svm   bi  term topic modeling  btm . furthermore  review paper also highlight real  world application topic model. several evaluation method use evaluate model  performance  discuss study. conclude mention huge future research scope topic modeling bangla '

# %% [markdown]
# ### Keywords

# %%
from nltk.stem.snowball import SnowballStemmer

# create a Snowball Stemmer object for stemming
stemmer = SnowballStemmer("english")

def stem_text(text):
    '''Apply stemming on text '''
    # build a list of keywords
    keywords = text.split(',')
    
    # apply stemming to each keywords
    stems = []
    stems.append(' '.join([stemmer.stem(word) for word in text.split(' ')]))
    
    # return processed text, after apply stemming
    return ', '.join(stems)

# %%
# convert text to lower case
data['Keywords_Cleaned'] = data['Keywords'].map(lambda text: text.lower())

# remove dash from text
data['Keywords_Cleaned'] = data['Keywords_Cleaned'].map(lambda text: re.sub(r'-', ' ', text))

# apply stemming
data['Keywords_Cleaned'] = data['Keywords_Cleaned'].apply(stem_text)

# look at the first five keywords
data['Keywords_Cleaned'].head()
# Out:
# 0    english bangla comparison, latent dirichlet al...
# 1    arab dataset, arab benchmark, arab recognition...
# 2    air traffic control, collis avoidance, conflic...
# 3    strawberry, cherri fruit, accuracy, mobilenet,...
# 4    content filtering, spam detection, multimod da...
# Name: Keywords_Cleaned, dtype: object

# %% [markdown]
# ## Save Data

# %%
data.to_csv('data/data_cleaned.csv', index=False)
